# %% [markdown]
# # MRMC Basic Results

# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '../..'))

# %load_ext autoreload
# %autoreload 2

import numba
import pandas as pd
import numpy as np
from sklearn import neighbors
from sklearn import model_selection

import matplotlib.pyplot as plt
import seaborn as sns
from models import model_interface, model_loader, model_constants
from data import data_loader
from data.adapters import continuous_adapter
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Preliminaries -- load everything

# %%
DATASET, VAL_DATASET, DATASET_INFO = data_loader.load_data(data_loader.DatasetName('credit_card_default'), split=["train", "val"])
MODEL = model_loader.load_model(model_constants.ModelType('logistic_regression'), data_loader.DatasetName('credit_card_default'))
ADAPTER = continuous_adapter.StandardizingAdapter(
    label_column = DATASET_INFO.label_column, positive_label=DATASET_INFO.positive_label
).fit(DATASET)

results_dir = '../../experiment_results/mrmc/mrmc_hyperparam'

cluster_df = pd.read_csv(os.path.join(results_dir, 'cluster_df.csv'))
index_df = pd.read_csv(os.path.join(results_dir, 'experiment_config_df.csv'))
path_df = pd.read_csv(os.path.join(results_dir, 'mrmc_paths_df.csv'))
index_df
# Out:
#       batch_id  run_id  run_seed  cluster_seed  confidence_cutoff  \
# 0           57    1734      3069       1834823                0.8
# 1           37    1121      7699       1834823                0.7
# 2           54    1626      4340       1834823                0.8
# 3           19     594      3069       1834823                0.6
# 4           27     818      5323       1834823                0.7
# ...        ...     ...       ...           ...                ...
# 2395        48    1466      7142       1834823                0.8
# 2396        71    2151      9251       1834823                0.9
# 2397         2      87      1393       1834823                0.6
# 2398        79    2381      7699       1834823                0.9
# 2399        77    2322      4470       1834823                0.9
#
#              dataset_name  max_iterations           model_type  noise_ratio  \
# 0     credit_card_default              50  logistic_regression          NaN
# 1     credit_card_default              50  logistic_regression          NaN
# 2     credit_card_default              50  logistic_regression          NaN
# 3     credit_card_default              50  logistic_regression          NaN
# 4     credit_card_default              50  logistic_regression          NaN
# ...                   ...             ...                  ...          ...
# 2395  credit_card_default              50  logistic_regression          NaN
# 2396  credit_card_default              50  logistic_regression          NaN
# 2397  credit_card_default              50  logistic_regression          NaN
# 2398  credit_card_default              50  logistic_regression          NaN
# 2399  credit_card_default              50  logistic_regression          NaN
#
#       num_clusters  rescale_ratio split  step_size  volcano_cutoff  \
# 0                5            NaN   val        1.0             0.5
# 1                5            NaN   val        1.0             0.5
# 2                4            NaN   val        2.0             0.5
# 3                5            NaN   val        4.0             0.5
# 4                2            NaN   val        4.0             0.5
# ...            ...            ...   ...        ...             ...
# 2395             3            NaN   val        0.5             0.5
# 2396             3            NaN   val        4.0             0.5
# 2397             1            NaN   val        2.0             0.5
# 2398             5            NaN   val        4.0             0.5
# 2399             5            NaN   val        1.0             0.5
#
#       volcano_degree  elapsed_recourse_seconds  elapsed_cluster_seconds
# 0                  2                  8.980880                 0.409453
# 1                  2                  3.723822                 0.240846
# 2                  2                  1.702643                 0.171854
# 3                  2                  1.970466                 0.299895
# 4                  2                  0.531205                 0.118892
# ...              ...                       ...                      ...
# 2395               2                  4.427919                 0.108565
# 2396               2                  1.268930                 0.097507
# 2397               2                  0.525432                 0.115893
# 2398               2                  1.746224                 0.101907
# 2399               2                  6.710612                 0.101346
#
# [2400 rows x 17 columns]

# %%
DROP_COLUMNS = ['step_id', 'path_id', 'run_id', 'batch_id']

# %% [markdown]
# ## Fit a KDE

# %%
kfold = model_selection.KFold(n_splits=5)
transformed_data = ADAPTER.transform(DATASET.drop(columns='Y')).sample(frac=1, replace=False)

bandwidths = np.logspace(-1, 0, 6)
scores = []

for bw in bandwidths:
    print("Evaluate bandwidth", bw)
    score = 0
    for train_indices, val_indices in kfold.split(transformed_data):
        kde = neighbors.KernelDensity(bandwidth=bw).fit(transformed_data.iloc[train_indices])
        score += kde.score(transformed_data.iloc[val_indices])
    scores.append(score / len(bandwidths))
    print(scores[-1])
best_bandwidth = bandwidths[np.argmax(scores)]
print("Finished! Selected bandwidth is ", best_bandwidth)
KDE = neighbors.KernelDensity(bandwidth=bw).fit(transformed_data)
print("Scoring full dataset...")
scores = KDE.score_samples(transformed_data)
# Out:
# Evaluate bandwidth 0.1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [205], line 12
#      10 for train_indices, val_indices in kfold.split(transformed_data):
#      11     kde = neighbors.KernelDensity(bandwidth=bw).fit(transformed_data.iloc[train_indices])
# ---> 12     score += kde.score(transformed_data.iloc[val_indices])
#      13 scores.append(score / len(bandwidths))
#      14 print(scores[-1])
#
# File ~/umass/research/.venv/lib/python3.8/site-packages/sklearn/neighbors/_kde.py:271, in KernelDensity.score(self, X, y)
#     251 def score(self, X, y=None):
#     252     """Compute the total log-likelihood under the model.
#     253
#     254     Parameters
#    (...)
#     269         data.
#     270     """
# --> 271     return np.sum(self.score_samples(X))
#
# File ~/umass/research/.venv/lib/python3.8/site-packages/sklearn/neighbors/_kde.py:239, in KernelDensity.score_samples(self, X)
#     237     N = self.tree_.sum_weight
#     238 atol_N = self.atol * N
# --> 239 log_density = self.tree_.kernel_density(
#     240     X,
#     241     h=self.bandwidth,
#     242     kernel=self.kernel,
#     243     atol=atol_N,
#     244     rtol=self.rtol,
#     245     breadth_first=self.breadth_first,
#     246     return_log=True,
#     247 )
#     248 log_density -= np.log(N)
#     249 return log_density
#
# KeyboardInterrupt:

# %% [markdown]
# ### Evaluate the KDE qualitatively
#
# The scores are between -28 and -20. Unsurprisingly, most points have relatively high density.
# Overall the histogram seems reasonable.

# %%
# best_bandwidth = bandwidths[np.argmax(scores)]
transformed_data = ADAPTER.transform(DATASET.drop(columns='Y'))
best_bandwidth = 0.251188643150958
KDE = neighbors.KernelDensity(bandwidth=best_bandwidth).fit(transformed_data)
if False:
    KDE_SCORES = KDE.score_samples(transformed_data)
    sns.histplot(KDE_SCORES)
    pd.DataFrame({'density': KDE_SCORES}).describe()

# %% [markdown]
# # Analyze the results

# %%
def get_poi_cfes(path_df):
    pathscopy = path_df.copy()
    pathscopy['next_step_id'] = 0
    pathscopy.loc[:,'next_step_id'].iloc[0:-1] = pathscopy.loc[:,'step_id'].iloc[1:]
    cfes = pathscopy[pathscopy.step_id > pathscopy.next_step_id].drop(columns='next_step_id')
    return pathscopy[pathscopy.step_id == 0].drop(columns='next_step_id'), cfes

# %%
pois, cfes = get_poi_cfes(path_df)
# Out:
# /tmp/ipykernel_30459/2754016615.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pathscopy.loc[:,'next_step_id'].iloc[0:-1] = pathscopy.loc[:,'step_id'].iloc[1:]

# %%
def get_sparsity2(path: pd.DataFrame):
    if path.shape[0] == 1:
        return np.nan
    path_sparsity = np.zeros(path.shape[0])
    for i in range(1, path.shape[0]):
        path_sparsity[i] = (np.abs(path.iloc[i] - path.iloc[i - 1]) > SPARSITY_EPSILON).sum()
    return np.max(path_sparsity)

def get_path_length2(path: pd.DataFrame):
    total = 0
    for i in range(1, path.shape[0]):
        total += np.linalg.norm(path.iloc[i] - path.iloc[i - 1])
    if total == 0:
        return np.nan
    return total

def get_cfe_distance2(path: pd.DataFrame):
    if len(path) == 1:
        return np.nan
    return np.linalg.norm(path.iloc[-1] - path.iloc[0])

# %%
poi_kdes = KDE.score_samples(ADAPTER.transform(pois.drop(columns=DROP_COLUMNS)))
cfe_kdes = KDE.score_samples(ADAPTER.transform(cfes.drop(columns=DROP_COLUMNS)))
cfe_probs = MODEL.predict_pos_proba(cfes.drop(columns=DROP_COLUMNS)).to_numpy()

# %%
def analyze_paths2(paths: pd.DataFrame, poi_kdes, cfe_kdes, cfe_probs, config_df):
    columns = ['run_id', 'path_id', 'success', 'proximity', 'path_length', 'iteration_count', 'poi_density', 'cfe_density', 'actual_sparsity']
    col_idx = {}
    for i, col in enumerate(columns):
        col_idx[col] = i

    results = np.zeros((len(poi_kdes), len(columns)))

    i = 0
    for run_id in paths.run_id.unique():
        run_paths = paths[paths.run_id == run_id]
        for path_id in run_paths.path_id.unique():
            path = ADAPTER.transform(run_paths[run_paths.path_id == path_id].drop(columns=DROP_COLUMNS))
            results[i,col_idx['run_id']] = run_id
            results[i,col_idx['path_id']] = path_id

            desired_proba = config_df[config_df.run_id == run_id].confidence_cutoff.iloc[0]
            actual_proba = cfe_probs[i]

            results[i,col_idx['success']] = 1 if actual_proba >= desired_proba else 0
            results[i,col_idx['path_length']] = get_path_length2(path)
            results[i,col_idx['iteration_count']] = len(path)
            results[i,col_idx['proximity']] = get_cfe_distance2(path)
            results[i,col_idx['poi_density']] = poi_kdes[i]
            results[i,col_idx['cfe_density']] = cfe_kdes[i]
            results[i,col_idx['actual_sparsity']] = get_sparsity2(path)
            i += 1

    return pd.DataFrame(data=results, columns=columns)

results = analyze_paths2(path_df, poi_kdes, cfe_kdes, cfe_probs, index_df)
results = results.merge(index_df, how='left', on='run_id').drop(columns=['dataset_name', 'max_iterations', 'model_type', 'noise_ratio', 'rescale_ratio', 'cluster_seed', 'run_seed', 'split', 'volcano_degree', 'volcano_cutoff'])

# %%
results
# Out:
#       run_id  path_id  success  proximity  path_length  iteration_count  \
# 0     1734.0      0.0      1.0  14.999508         15.0             16.0
# 1     1734.0      1.0      1.0  10.976130         11.0             12.0
# 2     1734.0      2.0      1.0  11.994732         12.0             13.0
# 3     1734.0      3.0      1.0  12.938918         13.0             14.0
# 4     1734.0      4.0      1.0  17.000000         17.0             18.0
# ...      ...      ...      ...        ...          ...              ...
# 7195  2322.0      0.0      1.0   7.943979          8.0              9.0
# 7196  2322.0      1.0      1.0  13.000000         13.0             14.0
# 7197  2322.0      2.0      1.0  11.987505         12.0             13.0
# 7198  2322.0      3.0      1.0  11.999804         12.0             13.0
# 7199  2322.0      4.0      1.0   8.979610          9.0             10.0
#
#       poi_density  cfe_density  actual_sparsity  batch_id  confidence_cutoff  \
# 0      -69.439821  -589.403415             20.0        57                0.8
# 1      -69.439821   -20.181228             20.0        57                0.8
# 2      -69.439821   -27.186152             20.0        57                0.8
# 3      -69.439821   -10.801940             20.0        57                0.8
# 4      -69.439821 -1376.763384             20.0        57                0.8
# ...           ...          ...              ...       ...                ...
# 7195   -10.073772   -36.069301             19.0        77                0.9
# 7196   -10.073772   -32.735419             15.0        77                0.9
# 7197   -10.073772   -26.730469             16.0        77                0.9
# 7198   -10.073772  -193.315758             15.0        77                0.9
# 7199   -10.073772   -55.916960             16.0        77                0.9
#
#       num_clusters  step_size  elapsed_recourse_seconds  \
# 0                5        1.0                  8.980880
# 1                5        1.0                  8.980880
# 2                5        1.0                  8.980880
# 3                5        1.0                  8.980880
# 4                5        1.0                  8.980880
# ...            ...        ...                       ...
# 7195             5        1.0                  6.710612
# 7196             5        1.0                  6.710612
# 7197             5        1.0                  6.710612
# 7198             5        1.0                  6.710612
# 7199             5        1.0                  6.710612
#
#       elapsed_cluster_seconds
# 0                    0.409453
# 1                    0.409453
# 2                    0.409453
# 3                    0.409453
# 4                    0.409453
# ...                       ...
# 7195                 0.101346
# 7196                 0.101346
# 7197                 0.101346
# 7198                 0.101346
# 7199                 0.101346
#
# [7200 rows x 15 columns]

# %% [markdown]
# # Let's look at the average metrics across the full batch
#
# * StEP never fails
# * As we add more clusters, the path_length and proximity increases. This is not surprising since it just an average and we will add some distant clusters

# %%
results['negative_cfe_density'] = -results['cfe_density']
results.groupby('batch_id').mean().sort_values(['success', 'path_length', 'proximity', 'negative_cfe_density', 'iteration_count'])
# Out:
#           run_id  path_id  success  proximity  path_length  iteration_count  \
# batch_id
# 0           14.5      0.0      1.0   4.682907     4.700000        10.400000
# 1           44.5      0.0      1.0   4.946972     4.966667         5.966667
# 8          254.5      1.0      1.0   5.204670     5.211111        11.422222
# 4          134.5      0.5      1.0   5.306274     5.316667        11.633333
# 20         614.5      0.0      1.0   5.322702     5.383333        11.766667
# ...          ...      ...      ...        ...          ...              ...
# 78        2354.5      2.0      1.0  12.338504    12.360000         7.180000
# 74        2234.5      1.5      1.0  12.627543    12.650000         7.325000
# 71        2144.5      1.0      1.0  12.670352    12.711111         4.177778
# 79        2384.5      2.0      1.0  13.301341    13.333333         4.333333
# 75        2264.5      1.5      1.0  13.436610    13.466667         4.366667
#
#           poi_density  cfe_density  actual_sparsity  confidence_cutoff  \
# batch_id
# 0           -6.874009     0.001315        20.000000                0.6
# 1           -6.874009     0.705603        20.000000                0.6
# 8           -6.874009   -10.911741        20.000000                0.6
# 4           -6.874009    -1.707263        20.000000                0.6
# 20          -6.874009    -1.270549        20.000000                0.7
# ...               ...          ...              ...                ...
# 78          -6.874009  -209.488909        17.680000                0.9
# 74          -6.874009  -248.471048        17.708333                0.9
# 71          -6.874009  -120.893412        17.977778                0.9
# 79          -6.874009  -249.952401        17.680000                0.9
# 75          -6.874009  -298.527709        17.708333                0.9
#
#           num_clusters  step_size  elapsed_recourse_seconds  \
# batch_id
# 0                  1.0        0.5                  1.869200
# 1                  1.0        1.0                  0.946551
# 8                  3.0        0.5                  5.687145
# 4                  2.0        0.5                  3.813711
# 20                 1.0        0.5                  1.919914
# ...                ...        ...                       ...
# 78                 5.0        2.0                  4.875358
# 74                 4.0        2.0                  4.462756
# 71                 3.0        4.0                  1.639463
# 79                 5.0        4.0                  2.676083
# 75                 4.0        4.0                  2.167497
#
#           elapsed_cluster_seconds  negative_cfe_density
# batch_id
# 0                        0.239150             -0.001315
# 1                        0.206301             -0.705603
# 8                        0.726430             10.911741
# 4                        0.327369              1.707263
# 20                       0.178869              1.270549
# ...                           ...                   ...
# 78                       0.156033            209.488909
# 74                       0.177279            248.471048
# 71                       0.148728            120.893412
# 79                       0.156859            249.952401
# 75                       0.161495            298.527709
#
# [80 rows x 15 columns]

# %%
results.groupby('num_clusters').mean()
# Out:
#               run_id  path_id  success  proximity  path_length  \
# num_clusters
# 1              959.5      0.0      1.0   6.765703     6.811458
# 2             1079.5      0.5      1.0   8.155375     8.183333
# 3             1199.5      1.0      1.0   8.388153     8.414931
# 4             1319.5      1.5      1.0   8.944341     8.968490
# 5             1439.5      2.0      1.0   8.967871     8.983750
#
#               iteration_count  poi_density  cfe_density  actual_sparsity  \
# num_clusters
# 1                    7.043750    -6.874009   -20.671983        20.000000
# 2                    8.314583    -6.874009   -73.090465        19.233333
# 3                    8.530556    -6.874009   -58.000682        19.091667
# 4                    9.048438    -6.874009  -111.566011        18.568750
# 5                    9.049583    -6.874009  -113.190247        18.525000
#
#               batch_id  confidence_cutoff  step_size  \
# num_clusters
# 1                 31.5               0.75      1.875
# 2                 35.5               0.75      1.875
# 3                 39.5               0.75      1.875
# 4                 43.5               0.75      1.875
# 5                 47.5               0.75      1.875
#
#               elapsed_recourse_seconds  elapsed_cluster_seconds  \
# num_clusters
# 1                             1.072867                 0.175793
# 2                             2.461483                 0.242431
# 3                             3.821646                 0.356476
# 4                             5.326257                 0.397984
# 5                             6.614835                 0.396594
#
#               negative_cfe_density
# num_clusters
# 1                        20.671983
# 2                        73.090465
# 3                        58.000682
# 4                       111.566011
# 5                       113.190247

# %%
results.groupby('step_size').mean()
# Out:
#            run_id   path_id  success  proximity  path_length  iteration_count  \
# step_size
# 0.5        1234.5  1.333333      1.0   7.938186     7.955278        16.910556
# 1.0        1264.5  1.333333      1.0   8.175836     8.195556         9.195556
# 2.0        1294.5  1.333333      1.0   8.664471     8.688889         5.344444
# 4.0        1324.5  1.333333      1.0   9.583543     9.617778         3.404444
#
#            poi_density  cfe_density  actual_sparsity   batch_id  \
# step_size
# 0.5          -6.874009   -81.854433        18.842778  40.666667
# 1.0          -6.874009   -82.539688        18.842778  41.666667
# 2.0          -6.874009   -90.025806        18.842778  42.666667
# 4.0          -6.874009  -106.398803        18.842778  43.666667
#
#            confidence_cutoff  num_clusters  elapsed_recourse_seconds  \
# step_size
# 0.5                     0.75      3.666667                  9.879722
# 1.0                     0.75      3.666667                  5.056373
# 2.0                     0.75      3.666667                  2.741888
# 4.0                     0.75      3.666667                  1.479342
#
#            elapsed_cluster_seconds  negative_cfe_density
# step_size
# 0.5                       0.356838             81.854433
# 1.0                       0.340741             82.539688
# 2.0                       0.382282             90.025806
# 4.0                       0.334802            106.398803

# %%
results.groupby('confidence_cutoff').mean()
# Out:
#                    run_id   path_id  success  proximity  path_length  \
# confidence_cutoff
# 0.6                 379.5  1.333333      1.0   6.196373     6.206389
# 0.7                 979.5  1.333333      1.0   7.358536     7.393611
# 0.8                1579.5  1.333333      1.0   8.973664     8.998611
# 0.9                2179.5  1.333333      1.0  11.833463    11.858889
#
#                    iteration_count  poi_density  cfe_density  actual_sparsity  \
# confidence_cutoff
# 0.6                       6.441667    -6.874009   -35.945609        19.591111
# 0.7                       7.581667    -6.874009   -42.457234        19.280000
# 0.8                       9.061667    -6.874009  -107.852073        18.493333
# 0.9                      11.770000    -6.874009  -174.563813        18.006667
#
#                     batch_id  num_clusters  step_size  \
# confidence_cutoff
# 0.6                12.166667      3.666667      1.875
# 0.7                32.166667      3.666667      1.875
# 0.8                52.166667      3.666667      1.875
# 0.9                72.166667      3.666667      1.875
#
#                    elapsed_recourse_seconds  elapsed_cluster_seconds  \
# confidence_cutoff
# 0.6                                3.602542                 0.629375
# 0.7                                4.229235                 0.373598
# 0.8                                4.929209                 0.258390
# 0.9                                6.396340                 0.153300
#
#                    negative_cfe_density
# confidence_cutoff
# 0.6                           35.945609
# 0.7                           42.457234
# 0.8                          107.852073
# 0.9                          174.563813

# %% [markdown]
# # Choosing parameters:
#
# * As you require higher confidence,
#   - CFE density is lower
#   - proximity is higher
#   - path length is higher
#   - iteration count increases
#
# * As you request more clusters,
#   - proximity and path length are slightly increased
#   - density is higher
#   - iteration count slightly increases
#
# * As you give larger step sizes,
#   - same observations as before, but it's not drastic
#   - iteration count decreases
#
#
# Paramset 1:  we want proximal points, iteration count doesn't matter
# * 3 clusters <- chosen for convenience
# * confidence 0.6 <- this is the best-ranked
# * 0.5 step size <- this is the best-ranked
#
#
# Paramset 2:  we want high-confidence points with low iteration count
# * 3 clusters
# * confidence 0.8
# * 4 step size <- this is best-ranked for low iteration count

# %%
results['density_difference'] = results['poi_density'] - results['cfe_density']

# %%
sns.histplot(results[results.density_difference < 100], x='density_difference')
# Out:
# <AxesSubplot: xlabel='density_difference', ylabel='Count'>

# %%
avg_results = results.groupby('batch_id').mean()

# %%
avg_results[avg_results.density_difference <= 0]
# Out:
#           run_id  path_id  success  proximity  path_length  poi_density  \
# batch_id
# 0           14.5      0.0      1.0   4.682907     4.700000    -6.874009
# 1           44.5      0.0      1.0   4.946972     4.966667    -6.874009
# 2           74.5      0.0      1.0   5.440978     5.466667    -6.874009
# 4          134.5      0.5      1.0   5.306274     5.316667    -6.874009
# 5          164.5      0.5      1.0   5.522126     5.533333    -6.874009
# 6          194.5      0.5      1.0   6.019660     6.033333    -6.874009
# 20         614.5      0.0      1.0   5.322702     5.383333    -6.874009
# 21         644.5      0.0      1.0   5.525584     5.600000    -6.874009
# 22         674.5      0.0      1.0   5.916247     6.000000    -6.874009
# 24         734.5      0.5      1.0   6.559517     6.600000    -6.874009
# 25         764.5      0.5      1.0   6.768190     6.816667    -6.874009
# 26         794.5      0.5      1.0   7.263711     7.333333    -6.874009
#
#           cfe_density  actual_sparsity  confidence_cutoff  num_clusters  \
# batch_id
# 0            0.001315             20.0                0.6           1.0
# 1            0.705603             20.0                0.6           1.0
# 2           -0.827490             20.0                0.6           1.0
# 4           -1.707263             20.0                0.6           2.0
# 5           -1.147836             20.0                0.6           2.0
# 6           -1.606514             20.0                0.6           2.0
# 20          -1.270549             20.0                0.7           1.0
# 21          -1.322610             20.0                0.7           1.0
# 22          -3.678051             20.0                0.7           1.0
# 24          -1.977771             20.0                0.7           2.0
# 25          -1.991131             20.0                0.7           2.0
# 26          -3.526690             20.0                0.7           2.0
#
#           step_size  elapsed_recourse_seconds  elapsed_cluster_seconds  \
# batch_id
# 0               0.5                  1.869200                 0.239150
# 1               1.0                  0.946551                 0.206301
# 2               2.0                  0.516620                 0.198520
# 4               0.5                  3.813711                 0.327369
# 5               1.0                  1.960824                 0.283712
# 6               2.0                  1.053803                 0.344702
# 20              0.5                  1.919914                 0.178869
# 21              1.0                  1.115797                 0.196995
# 22              2.0                  0.539779                 0.189563
# 24              0.5                  4.516534                 0.239051
# 25              1.0                  2.678444                 0.329990
# 26              2.0                  1.291586                 0.304608
#
#           negative_cfe_density  density_difference
# batch_id
# 0                    -0.001315           -6.875323
# 1                    -0.705603           -7.579612
# 2                     0.827490           -6.046519
# 4                     1.707263           -5.166745
# 5                     1.147836           -5.726173
# 6                     1.606514           -5.267494
# 20                    1.270549           -5.603460
# 21                    1.322610           -5.551399
# 22                    3.678051           -3.195957
# 24                    1.977771           -4.896237
# 25                    1.991131           -4.882878
# 26                    3.526690           -3.347318

# %%
avg_results[(avg_results.density_difference > 0) & (avg_results.density_difference <= 10)]
# Out:
#           run_id  path_id  success  proximity  path_length  poi_density  \
# batch_id
# 3          104.5      0.0      1.0   6.368068     6.400000    -6.874009
# 7          224.5      0.5      1.0   7.111368     7.133333    -6.874009
# 8          254.5      1.0      1.0   5.204670     5.211111    -6.874009
# 9          284.5      1.0      1.0   5.470641     5.477778    -6.874009
# 10         314.5      1.0      1.0   5.925028     5.933333    -6.874009
# 27         824.5      0.5      1.0   7.995916     8.066667    -6.874009
# 28         854.5      1.0      1.0   6.468292     6.488889    -6.874009
# 29         884.5      1.0      1.0   6.697666     6.722222    -6.874009
# 30         914.5      1.0      1.0   7.167584     7.200000    -6.874009
#
#           cfe_density  actual_sparsity  confidence_cutoff  num_clusters  \
# batch_id
# 3          -15.760410        20.000000                0.6           1.0
# 7          -13.608876        20.000000                0.6           2.0
# 8          -10.911741        20.000000                0.6           3.0
# 9          -10.112508        20.000000                0.6           3.0
# 10         -10.363891        20.000000                0.6           3.0
# 27         -15.384429        20.000000                0.7           2.0
# 28         -12.991704        19.766667                0.7           3.0
# 29         -14.013208        19.766667                0.7           3.0
# 30         -14.188215        19.766667                0.7           3.0
#
#           step_size  elapsed_recourse_seconds  elapsed_cluster_seconds  \
# batch_id
# 3               4.0                  0.324168                 0.208373
# 7               4.0                  0.647075                 0.307291
# 8               0.5                  5.687145                 0.726430
# 9               1.0                  2.984896                 0.616626
# 10              2.0                  1.657948                 0.691178
# 27              4.0                  0.702425                 0.246867
# 28              0.5                  6.877510                 0.377136
# 29              1.0                  3.604323                 0.383472
# 30              2.0                  1.851315                 0.320940
#
#           negative_cfe_density  density_difference
# batch_id
# 3                    15.760410            8.886402
# 7                    13.608876            6.734867
# 8                    10.911741            4.037732
# 9                    10.112508            3.238499
# 10                   10.363891            3.489883
# 27                   15.384429            8.510420
# 28                   12.991704            6.117695
# 29                   14.013208            7.139199
# 30                   14.188215            7.314206

# %%
avg_results[(avg_results.density_difference > 10) & (avg_results.density_difference <= 20)]
# Out:
#           run_id  path_id  success  proximity  path_length  poi_density  \
# batch_id
# 11         344.5      1.0      1.0   7.009084     7.022222    -6.874009
# 23         704.5      0.0      1.0   6.822626     6.933333    -6.874009
# 31         944.5      1.0      1.0   8.051394     8.088889    -6.874009
# 40        1214.5      0.0      1.0   6.230425     6.250000    -6.874009
# 41        1244.5      0.0      1.0   6.475969     6.500000    -6.874009
# 42        1274.5      0.0      1.0   6.903528     6.933333    -6.874009
#
#           cfe_density  actual_sparsity  confidence_cutoff  num_clusters  \
# batch_id
# 11         -18.369011        20.000000                0.6           3.0
# 23         -18.452472        20.000000                0.7           1.0
# 31         -23.336329        19.766667                0.7           3.0
# 40         -18.623445        20.000000                0.8           1.0
# 41         -18.745729        20.000000                0.8           1.0
# 42         -21.394250        20.000000                0.8           1.0
#
#           step_size  elapsed_recourse_seconds  elapsed_cluster_seconds  \
# batch_id
# 11              4.0                  0.894633                 0.589660
# 23              4.0                  0.348817                 0.192830
# 31              4.0                  1.121129                 0.398215
# 40              0.5                  2.221539                 0.172003
# 41              1.0                  1.177454                 0.159481
# 42              2.0                  0.661782                 0.183610
#
#           negative_cfe_density  density_difference
# batch_id
# 11                   18.369011           11.495002
# 23                   18.452472           11.578463
# 31                   23.336329           16.462320
# 40                   18.623445           11.749436
# 41                   18.745729           11.871720
# 42                   21.394250           14.520242

# %%
avg_results[(avg_results.density_difference > 100)]
# Out:
#           run_id  path_id  success  proximity  path_length  poi_density  \
# batch_id
# 44        1334.5      0.5      1.0   7.873166     7.883333    -6.874009
# 45        1364.5      0.5      1.0   8.070939     8.083333    -6.874009
# 46        1394.5      0.5      1.0   8.484687     8.500000    -6.874009
# 47        1424.5      0.5      1.0   9.635234     9.666667    -6.874009
# 56        1694.5      2.0      1.0   8.934466     8.943333    -6.874009
# 57        1724.5      2.0      1.0   9.215836     9.226667    -6.874009
# 58        1754.5      2.0      1.0   9.666281     9.680000    -6.874009
# 59        1784.5      2.0      1.0  10.717790    10.746667    -6.874009
# 64        1934.5      0.5      1.0  10.329963    10.350000    -6.874009
# 65        1964.5      0.5      1.0  10.594763    10.616667    -6.874009
# 66        1994.5      0.5      1.0  11.110300    11.133333    -6.874009
# 67        2024.5      0.5      1.0  11.840180    11.866667    -6.874009
# 70        2114.5      1.0      1.0  11.902806    11.933333    -6.874009
# 71        2144.5      1.0      1.0  12.670352    12.711111    -6.874009
# 72        2174.5      1.5      1.0  11.886309    11.904167    -6.874009
# 73        2204.5      1.5      1.0  12.105226    12.125000    -6.874009
# 74        2234.5      1.5      1.0  12.627543    12.650000    -6.874009
# 75        2264.5      1.5      1.0  13.436610    13.466667    -6.874009
# 76        2294.5      2.0      1.0  11.633242    11.650000    -6.874009
# 77        2324.5      2.0      1.0  11.828536    11.846667    -6.874009
# 78        2354.5      2.0      1.0  12.338504    12.360000    -6.874009
# 79        2384.5      2.0      1.0  13.301341    13.333333    -6.874009
#
#           cfe_density  actual_sparsity  confidence_cutoff  num_clusters  \
# batch_id
# 44        -134.100669        18.466667                0.8           2.0
# 45        -134.571349        18.466667                0.8           2.0
# 46        -121.697929        18.466667                0.8           2.0
# 47        -141.354946        18.466667                0.8           2.0
# 56        -125.706059        18.080000                0.8           5.0
# 57        -136.819847        18.080000                0.8           5.0
# 58        -145.226634        18.080000                0.8           5.0
# 59        -163.205475        18.080000                0.8           5.0
# 64        -141.298243        18.466667                0.9           2.0
# 65        -142.874169        18.466667                0.9           2.0
# 66        -146.930971        18.466667                0.9           2.0
# 67        -165.668646        18.466667                0.9           2.0
# 70        -107.266377        17.977778                0.9           3.0
# 71        -120.893412        17.977778                0.9           3.0
# 72        -203.889586        17.708333                0.9           4.0
# 73        -197.578296        17.708333                0.9           4.0
# 74        -248.471048        17.708333                0.9           4.0
# 75        -298.527709        17.708333                0.9           4.0
# 76        -170.556569        17.680000                0.9           5.0
# 77        -166.700230        17.680000                0.9           5.0
# 78        -209.488909        17.680000                0.9           5.0
# 79        -249.952401        17.680000                0.9           5.0
#
#           step_size  elapsed_recourse_seconds  elapsed_cluster_seconds  \
# batch_id
# 44              0.5                  5.471754                 0.240970
# 45              1.0                  2.634950                 0.219960
# 46              2.0                  1.371522                 0.218231
# 47              4.0                  0.854918                 0.248007
# 56              0.5                 14.636002                 0.288579
# 57              1.0                  7.224560                 0.280653
# 58              2.0                  3.912483                 0.340275
# 59              4.0                  2.024963                 0.237656
# 64              0.5                  6.325576                 0.132241
# 65              1.0                  3.321364                 0.134623
# 66              2.0                  1.783547                 0.153978
# 67              4.0                  0.955687                 0.147291
# 70              2.0                  2.867355                 0.145117
# 71              4.0                  1.639463                 0.148728
# 72              0.5                 14.276564                 0.143955
# 73              1.0                  7.951976                 0.161845
# 74              2.0                  4.462756                 0.177279
# 75              4.0                  2.167497                 0.161495
# 76              0.5                 18.154001                 0.160130
# 77              1.0                  9.428104                 0.169386
# 78              2.0                  4.875358                 0.156033
# 79              4.0                  2.676083                 0.156859
#
#           negative_cfe_density  density_difference
# batch_id
# 44                  134.100669          127.226660
# 45                  134.571349          127.697340
# 46                  121.697929          114.823920
# 47                  141.354946          134.480937
# 56                  125.706059          118.832050
# 57                  136.819847          129.945838
# 58                  145.226634          138.352625
# 59                  163.205475          156.331466
# 64                  141.298243          134.424234
# 65                  142.874169          136.000160
# 66                  146.930971          140.056963
# 67                  165.668646          158.794637
# 70                  107.266377          100.392368
# 71                  120.893412          114.019403
# 72                  203.889586          197.015577
# 73                  197.578296          190.704287
# 74                  248.471048          241.597039
# 75                  298.527709          291.653700
# 76                  170.556569          163.682560
# 77                  166.700230          159.826221
# 78                  209.488909          202.614900
# 79                  249.952401          243.078392

# %%
avg_results[avg_results.step_size == 4]
# Out:
#           run_id  path_id  success  proximity  path_length  poi_density  \
# batch_id
# 3          104.5      0.0      1.0   6.368068     6.400000    -6.874009
# 7          224.5      0.5      1.0   7.111368     7.133333    -6.874009
# 11         344.5      1.0      1.0   7.009084     7.022222    -6.874009
# 15         464.5      1.5      1.0   7.549901     7.566667    -6.874009
# 19         584.5      2.0      1.0   7.350604     7.360000    -6.874009
# 23         704.5      0.0      1.0   6.822626     6.933333    -6.874009
# 27         824.5      0.5      1.0   7.995916     8.066667    -6.874009
# 31         944.5      1.0      1.0   8.051394     8.088889    -6.874009
# 35        1064.5      1.5      1.0   8.621627     8.666667    -6.874009
# 39        1184.5      2.0      1.0   8.588336     8.613333    -6.874009
# 43        1304.5      0.0      1.0   8.204764     8.266667    -6.874009
# 47        1424.5      0.5      1.0   9.635234     9.666667    -6.874009
# 51        1544.5      1.0      1.0   9.763215     9.822222    -6.874009
# 55        1664.5      1.5      1.0  10.082479    10.133333    -6.874009
# 59        1784.5      2.0      1.0  10.717790    10.746667    -6.874009
# 63        1904.5      0.0      1.0   9.416746     9.466667    -6.874009
# 67        2024.5      0.5      1.0  11.840180    11.866667    -6.874009
# 71        2144.5      1.0      1.0  12.670352    12.711111    -6.874009
# 75        2264.5      1.5      1.0  13.436610    13.466667    -6.874009
# 79        2384.5      2.0      1.0  13.301341    13.333333    -6.874009
#
#           cfe_density  actual_sparsity  confidence_cutoff  num_clusters  \
# batch_id
# 3          -15.760410        20.000000                0.6           1.0
# 7          -13.608876        20.000000                0.6           2.0
# 11         -18.369011        20.000000                0.6           3.0
# 15         -69.019552        19.233333                0.6           4.0
# 19         -60.611849        19.386667                0.6           5.0
# 23         -18.452472        20.000000                0.7           1.0
# 27         -15.384429        20.000000                0.7           2.0
# 31         -23.336329        19.766667                0.7           3.0
# 35         -71.551453        18.783333                0.7           4.0
# 39         -61.502274        18.953333                0.7           5.0
# 43         -38.257446        20.000000                0.8           1.0
# 47        -141.354946        18.466667                0.8           2.0
# 51        -101.457399        18.622222                0.8           3.0
# 55         -89.888071        18.550000                0.8           4.0
# 59        -163.205475        18.080000                0.8           5.0
# 63         -54.948456        20.000000                0.9           1.0
# 67        -165.668646        18.466667                0.9           2.0
# 71        -120.893412        17.977778                0.9           3.0
# 75        -298.527709        17.708333                0.9           4.0
# 79        -249.952401        17.680000                0.9           5.0
#
#           step_size  elapsed_recourse_seconds  elapsed_cluster_seconds  \
# batch_id
# 3               4.0                  0.324168                 0.208373
# 7               4.0                  0.647075                 0.307291
# 11              4.0                  0.894633                 0.589660
# 15              4.0                  1.378287                 0.770334
# 19              4.0                  1.540454                 0.683687
# 23              4.0                  0.348817                 0.192830
# 27              4.0                  0.702425                 0.246867
# 31              4.0                  1.121129                 0.398215
# 35              4.0                  1.451080                 0.401497
# 39              4.0                  1.732861                 0.325936
# 43              4.0                  0.364234                 0.161971
# 47              4.0                  0.854918                 0.248007
# 51              4.0                  1.207812                 0.221864
# 55              4.0                  1.640539                 0.266202
# 59              4.0                  2.024963                 0.237656
# 63              4.0                  0.392571                 0.131835
# 67              4.0                  0.955687                 0.147291
# 71              4.0                  1.639463                 0.148728
# 75              4.0                  2.167497                 0.161495
# 79              4.0                  2.676083                 0.156859
#
#           negative_cfe_density  density_difference
# batch_id
# 3                    15.760410            8.886402
# 7                    13.608876            6.734867
# 11                   18.369011           11.495002
# 15                   69.019552           62.145543
# 19                   60.611849           53.737841
# 23                   18.452472           11.578463
# 27                   15.384429            8.510420
# 31                   23.336329           16.462320
# 35                   71.551453           64.677444
# 39                   61.502274           54.628266
# 43                   38.257446           31.383437
# 47                  141.354946          134.480937
# 51                  101.457399           94.583391
# 55                   89.888071           83.014062
# 59                  163.205475          156.331466
# 63                   54.948456           48.074447
# 67                  165.668646          158.794637
# 71                  120.893412          114.019403
# 75                  298.527709          291.653700
# 79                  249.952401          243.078392

# %%
avg_results[avg_results.step_size == 4]
# Out:
#           run_id  path_id  success  proximity  path_length  poi_density  \
# batch_id
# 3          104.5      0.0      1.0   6.368068     6.400000    -6.874009
# 7          224.5      0.5      1.0   7.111368     7.133333    -6.874009
# 11         344.5      1.0      1.0   7.009084     7.022222    -6.874009
# 15         464.5      1.5      1.0   7.549901     7.566667    -6.874009
# 19         584.5      2.0      1.0   7.350604     7.360000    -6.874009
# 23         704.5      0.0      1.0   6.822626     6.933333    -6.874009
# 27         824.5      0.5      1.0   7.995916     8.066667    -6.874009
# 31         944.5      1.0      1.0   8.051394     8.088889    -6.874009
# 35        1064.5      1.5      1.0   8.621627     8.666667    -6.874009
# 39        1184.5      2.0      1.0   8.588336     8.613333    -6.874009
# 43        1304.5      0.0      1.0   8.204764     8.266667    -6.874009
# 47        1424.5      0.5      1.0   9.635234     9.666667    -6.874009
# 51        1544.5      1.0      1.0   9.763215     9.822222    -6.874009
# 55        1664.5      1.5      1.0  10.082479    10.133333    -6.874009
# 59        1784.5      2.0      1.0  10.717790    10.746667    -6.874009
# 63        1904.5      0.0      1.0   9.416746     9.466667    -6.874009
# 67        2024.5      0.5      1.0  11.840180    11.866667    -6.874009
# 71        2144.5      1.0      1.0  12.670352    12.711111    -6.874009
# 75        2264.5      1.5      1.0  13.436610    13.466667    -6.874009
# 79        2384.5      2.0      1.0  13.301341    13.333333    -6.874009
#
#           cfe_density  actual_sparsity  confidence_cutoff  num_clusters  \
# batch_id
# 3          -15.760410        20.000000                0.6           1.0
# 7          -13.608876        20.000000                0.6           2.0
# 11         -18.369011        20.000000                0.6           3.0
# 15         -69.019552        19.233333                0.6           4.0
# 19         -60.611849        19.386667                0.6           5.0
# 23         -18.452472        20.000000                0.7           1.0
# 27         -15.384429        20.000000                0.7           2.0
# 31         -23.336329        19.766667                0.7           3.0
# 35         -71.551453        18.783333                0.7           4.0
# 39         -61.502274        18.953333                0.7           5.0
# 43         -38.257446        20.000000                0.8           1.0
# 47        -141.354946        18.466667                0.8           2.0
# 51        -101.457399        18.622222                0.8           3.0
# 55         -89.888071        18.550000                0.8           4.0
# 59        -163.205475        18.080000                0.8           5.0
# 63         -54.948456        20.000000                0.9           1.0
# 67        -165.668646        18.466667                0.9           2.0
# 71        -120.893412        17.977778                0.9           3.0
# 75        -298.527709        17.708333                0.9           4.0
# 79        -249.952401        17.680000                0.9           5.0
#
#           step_size  elapsed_recourse_seconds  elapsed_cluster_seconds  \
# batch_id
# 3               4.0                  0.324168                 0.208373
# 7               4.0                  0.647075                 0.307291
# 11              4.0                  0.894633                 0.589660
# 15              4.0                  1.378287                 0.770334
# 19              4.0                  1.540454                 0.683687
# 23              4.0                  0.348817                 0.192830
# 27              4.0                  0.702425                 0.246867
# 31              4.0                  1.121129                 0.398215
# 35              4.0                  1.451080                 0.401497
# 39              4.0                  1.732861                 0.325936
# 43              4.0                  0.364234                 0.161971
# 47              4.0                  0.854918                 0.248007
# 51              4.0                  1.207812                 0.221864
# 55              4.0                  1.640539                 0.266202
# 59              4.0                  2.024963                 0.237656
# 63              4.0                  0.392571                 0.131835
# 67              4.0                  0.955687                 0.147291
# 71              4.0                  1.639463                 0.148728
# 75              4.0                  2.167497                 0.161495
# 79              4.0                  2.676083                 0.156859
#
#           negative_cfe_density  density_difference
# batch_id
# 3                    15.760410            8.886402
# 7                    13.608876            6.734867
# 11                   18.369011           11.495002
# 15                   69.019552           62.145543
# 19                   60.611849           53.737841
# 23                   18.452472           11.578463
# 27                   15.384429            8.510420
# 31                   23.336329           16.462320
# 35                   71.551453           64.677444
# 39                   61.502274           54.628266
# 43                   38.257446           31.383437
# 47                  141.354946          134.480937
# 51                  101.457399           94.583391
# 55                   89.888071           83.014062
# 59                  163.205475          156.331466
# 63                   54.948456           48.074447
# 67                  165.668646          158.794637
# 71                  120.893412          114.019403
# 75                  298.527709          291.653700
# 79                  249.952401          243.078392

# %%
avg_results[avg_results.step_size == 2]
# Out:
#           run_id  path_id  success  proximity  path_length  poi_density  \
# batch_id
# 2           74.5      0.0      1.0   5.440978     5.466667    -6.874009
# 6          194.5      0.5      1.0   6.019660     6.033333    -6.874009
# 10         314.5      1.0      1.0   5.925028     5.933333    -6.874009
# 14         434.5      1.5      1.0   6.623078     6.633333    -6.874009
# 18         554.5      2.0      1.0   6.473438     6.480000    -6.874009
# 22         674.5      0.0      1.0   5.916247     6.000000    -6.874009
# 26         794.5      0.5      1.0   7.263711     7.333333    -6.874009
# 30         914.5      1.0      1.0   7.167584     7.200000    -6.874009
# 34        1034.5      1.5      1.0   7.808544     7.850000    -6.874009
# 38        1154.5      2.0      1.0   7.723811     7.746667    -6.874009
# 42        1274.5      0.0      1.0   6.903528     6.933333    -6.874009
# 46        1394.5      0.5      1.0   8.484687     8.500000    -6.874009
# 50        1514.5      1.0      1.0   8.808104     8.844444    -6.874009
# 54        1634.5      1.5      1.0   9.042565     9.066667    -6.874009
# 58        1754.5      2.0      1.0   9.666281     9.680000    -6.874009
# 62        1874.5      0.0      1.0   9.023168     9.066667    -6.874009
# 66        1994.5      0.5      1.0  11.110300    11.133333    -6.874009
# 70        2114.5      1.0      1.0  11.902806    11.933333    -6.874009
# 74        2234.5      1.5      1.0  12.627543    12.650000    -6.874009
# 78        2354.5      2.0      1.0  12.338504    12.360000    -6.874009
#
#           cfe_density  actual_sparsity  confidence_cutoff  num_clusters  \
# batch_id
# 2           -0.827490        20.000000                0.6           1.0
# 6           -1.606514        20.000000                0.6           2.0
# 10         -10.363891        20.000000                0.6           3.0
# 14         -59.363010        19.233333                0.6           4.0
# 18         -52.105625        19.386667                0.6           5.0
# 22          -3.678051        20.000000                0.7           1.0
# 26          -3.526690        20.000000                0.7           2.0
# 30         -14.188215        19.766667                0.7           3.0
# 34         -66.317005        18.783333                0.7           4.0
# 38         -57.554837        18.953333                0.7           5.0
# 42         -21.394250        20.000000                0.8           1.0
# 46        -121.697929        18.466667                0.8           2.0
# 50         -86.590815        18.622222                0.8           3.0
# 54         -76.420560        18.550000                0.8           4.0
# 58        -145.226634        18.080000                0.8           5.0
# 62         -48.729918        20.000000                0.9           1.0
# 66        -146.930971        18.466667                0.9           2.0
# 70        -107.266377        17.977778                0.9           3.0
# 74        -248.471048        17.708333                0.9           4.0
# 78        -209.488909        17.680000                0.9           5.0
#
#           step_size  elapsed_recourse_seconds  elapsed_cluster_seconds  \
# batch_id
# 2               2.0                  0.516620                 0.198520
# 6               2.0                  1.053803                 0.344702
# 10              2.0                  1.657948                 0.691178
# 14              2.0                  2.511713                 0.878951
# 18              2.0                  3.066645                 0.765703
# 22              2.0                  0.539779                 0.189563
# 26              2.0                  1.291586                 0.304608
# 30              2.0                  1.851315                 0.320940
# 34              2.0                  2.699378                 0.434022
# 38              2.0                  3.272090                 0.566488
# 42              2.0                  0.661782                 0.183610
# 46              2.0                  1.371522                 0.218231
# 50              2.0                  2.051862                 0.219792
# 54              2.0                  2.869658                 0.238403
# 58              2.0                  3.912483                 0.340275
# 62              2.0                  0.701838                 0.134005
# 66              2.0                  1.783547                 0.153978
# 70              2.0                  2.867355                 0.145117
# 74              2.0                  4.462756                 0.177279
# 78              2.0                  4.875358                 0.156033
#
#           negative_cfe_density  density_difference
# batch_id
# 2                     0.827490           -6.046519
# 6                     1.606514           -5.267494
# 10                   10.363891            3.489883
# 14                   59.363010           52.489001
# 18                   52.105625           45.231616
# 22                    3.678051           -3.195957
# 26                    3.526690           -3.347318
# 30                   14.188215            7.314206
# 34                   66.317005           59.442996
# 38                   57.554837           50.680828
# 42                   21.394250           14.520242
# 46                  121.697929          114.823920
# 50                   86.590815           79.716806
# 54                   76.420560           69.546552
# 58                  145.226634          138.352625
# 62                   48.729918           41.855909
# 66                  146.930971          140.056963
# 70                  107.266377          100.392368
# 74                  248.471048          241.597039
# 78                  209.488909          202.614900

# %% [markdown]
# # The mystery of the POI KDE

# %%
df = path_df.merge(index_df[['run_id', 'run_seed']], how='left', on='run_id')
pois = df[df.step_id == 0]
pois.groupby('run_seed').count()
# Out:
#           LIMIT_BAL  AGE  PAY_1  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1  \
# run_seed
# 51              240  240    240    240    240    240    240    240        240
# 171             240  240    240    240    240    240    240    240        240
# 211             240  240    240    240    240    240    240    240        240
# 227             240  240    240    240    240    240    240    240        240
# 478             240  240    240    240    240    240    240    240        240
# 1393            240  240    240    240    240    240    240    240        240
# 1498            240  240    240    240    240    240    240    240        240
# 1573            240  240    240    240    240    240    240    240        240
# 1701            240  240    240    240    240    240    240    240        240
# 1845            240  240    240    240    240    240    240    240        240
# 2020            240  240    240    240    240    240    240    240        240
# 3069            240  240    240    240    240    240    240    240        240
# 3183            240  240    240    240    240    240    240    240        240
# 3363            240  240    240    240    240    240    240    240        240
# 3439            240  240    240    240    240    240    240    240        240
# 4340            240  240    240    240    240    240    240    240        240
# 4404            240  240    240    240    240    240    240    240        240
# 4470            240  240    240    240    240    240    240    240        240
# 4526            240  240    240    240    240    240    240    240        240
# 5323            240  240    240    240    240    240    240    240        240
# 5403            240  240    240    240    240    240    240    240        240
# 5500            240  240    240    240    240    240    240    240        240
# 5653            240  240    240    240    240    240    240    240        240
# 6779            240  240    240    240    240    240    240    240        240
# 7142            240  240    240    240    240    240    240    240        240
# 7527            240  240    240    240    240    240    240    240        240
# 7699            240  240    240    240    240    240    240    240        240
# 8286            240  240    240    240    240    240    240    240        240
# 9251            240  240    240    240    240    240    240    240        240
# 9560            240  240    240    240    240    240    240    240        240
#
#           BILL_AMT2  ...  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# run_seed             ...
# 51              240  ...       240       240       240       240       240
# 171             240  ...       240       240       240       240       240
# 211             240  ...       240       240       240       240       240
# 227             240  ...       240       240       240       240       240
# 478             240  ...       240       240       240       240       240
# 1393            240  ...       240       240       240       240       240
# 1498            240  ...       240       240       240       240       240
# 1573            240  ...       240       240       240       240       240
# 1701            240  ...       240       240       240       240       240
# 1845            240  ...       240       240       240       240       240
# 2020            240  ...       240       240       240       240       240
# 3069            240  ...       240       240       240       240       240
# 3183            240  ...       240       240       240       240       240
# 3363            240  ...       240       240       240       240       240
# 3439            240  ...       240       240       240       240       240
# 4340            240  ...       240       240       240       240       240
# 4404            240  ...       240       240       240       240       240
# 4470            240  ...       240       240       240       240       240
# 4526            240  ...       240       240       240       240       240
# 5323            240  ...       240       240       240       240       240
# 5403            240  ...       240       240       240       240       240
# 5500            240  ...       240       240       240       240       240
# 5653            240  ...       240       240       240       240       240
# 6779            240  ...       240       240       240       240       240
# 7142            240  ...       240       240       240       240       240
# 7527            240  ...       240       240       240       240       240
# 7699            240  ...       240       240       240       240       240
# 8286            240  ...       240       240       240       240       240
# 9251            240  ...       240       240       240       240       240
# 9560            240  ...       240       240       240       240       240
#
#           PAY_AMT6  step_id  path_id  run_id  batch_id
# run_seed
# 51             240      240      240     240       240
# 171            240      240      240     240       240
# 211            240      240      240     240       240
# 227            240      240      240     240       240
# 478            240      240      240     240       240
# 1393           240      240      240     240       240
# 1498           240      240      240     240       240
# 1573           240      240      240     240       240
# 1701           240      240      240     240       240
# 1845           240      240      240     240       240
# 2020           240      240      240     240       240
# 3069           240      240      240     240       240
# 3183           240      240      240     240       240
# 3363           240      240      240     240       240
# 3439           240      240      240     240       240
# 4340           240      240      240     240       240
# 4404           240      240      240     240       240
# 4470           240      240      240     240       240
# 4526           240      240      240     240       240
# 5323           240      240      240     240       240
# 5403           240      240      240     240       240
# 5500           240      240      240     240       240
# 5653           240      240      240     240       240
# 6779           240      240      240     240       240
# 7142           240      240      240     240       240
# 7527           240      240      240     240       240
# 7699           240      240      240     240       240
# 8286           240      240      240     240       240
# 9251           240      240      240     240       240
# 9560           240      240      240     240       240
#
# [30 rows x 24 columns]

# %%
poi_kdes.mean()
# Out:
# -6.874008823061476

# %%
KDE.score_samples(ADAPTER.transform(pois.drop(columns=['step_id', 'path_id', 'run_id', 'batch_id', 'run_seed']))).mean()
# Out:
# -6.874008823061476

# %%
unique_pois = pois.drop_duplicates('run_seed').drop(columns=['step_id', 'path_id', 'run_id', 'batch_id', 'run_seed'])

# %%
KDE.score_samples(ADAPTER.transform(unique_pois)).mean()
# Out:
# -5.455148319625964

# %%
# -5.455148319625964
