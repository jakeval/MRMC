# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '..'))


# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


from experiments.dice_experiment import run_dice_experiment
from confidence_checks import toy_data, identity_adapter, toy_model, plotting_functions
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Set up the data, adapter, and model

# %% [markdown]
# ### Get the synthetic data
#
# The synthetic dataset has:
# * 1 negatively-classified POI at (-1, 0)
# * 1 positively-classified 4-point cluster at (0, 2)
# * 1 positively-classified 4-point cluster at (1, 2)

# %%
DATASET, DATASET_INFO = toy_data.get_data()
POI = DATASET.drop('label', axis=1).iloc[-1]

sns.scatterplot(x='x', y='y', hue="label", data=DATASET)
plt.title("Synthetic Dataset")
# Out:
# Text(0.5, 1.0, 'Synthetic Dataset')

# %% [markdown]
# ### Create a passthrough adapter
# For ease of debugging, the adapter doesn't transform the data.

# %%
ADAPTER = identity_adapter.IdentityAdapter(
    label_column=DATASET_INFO.label_column,
    positive_label=DATASET_INFO.positive_label
).fit(DATASET)

# %% [markdown]
# ### Create a simple model
#
# There is a low- to high-confidence gradient from (-1, 0) to (1, 2)

# %%
MODEL = toy_model.ToyModel(ADAPTER)


plotting_functions.plot_model_confidence(MODEL)
plt.title('Model Confidence Contours')
sns.scatterplot(x='x', y='y', hue='label', data=DATASET)
# Out:
# <AxesSubplot: title={'center': 'Model Confidence Contours'}, xlabel='x', ylabel='y'>

# %% [markdown]
# # Test executing batched run configs

# %% [markdown]
# ### Test dry run

# %%
batch_config = {
    "experiment_name": "test_batch",
    "run_configs": [
        {
            'mock_config': 'mock_value'
        },
        {
            'mock_config': 'mock_value'
        }
    ]
}

run_dice_experiment.main(
    config=batch_config,
    is_experiment=False,
    verbose=True,
    dry_run=True
)
# Out:
# Got configs for 2 runs.
# Terminate without executing runs because --dry_run is set.

# %% [markdown]
# ### Test two runs with same seeds and arguments

# %%
def show_results(results_path, label_column=None):
    print("\nResults saved as:")
    print(os.listdir(results_path))

    dice_paths_df = pd.read_csv(os.path.join(results_path, 'dice_paths_df.csv'))

    plotting_functions.plot_model_confidence(MODEL, xlim=(-1.1, 1.1), ylim=(0,2.2))
    sns.scatterplot(x='x', y='y', data=DATASET, label="Dataset")

    experiment_config_df = None
    if label_column:
        experiment_config_df = pd.read_csv(os.path.join(results_path, 'experiment_config_df.csv'))

    plotting_functions.plot_paths_results(
        dice_paths_df, alpha=0.8, label_column=label_column,
        experiment_config_df=experiment_config_df)
    plt.legend()

# %%
batch_config = {
    "experiment_name": "test_batch",
    "run_configs": [
        {
            "dataset_name": "toy_data",
            "model_type": "toy_model",
            "confidence_cutoff": 0.6,
            "noise_ratio": 0.2,
            "rescale_ratio": None,
            "num_paths": 2,
            "max_iterations": 10,
            "batch_id": 0,
            "run_id": 0,
            "run_seed": 0
        },
        {
            "dataset_name": "toy_data",
            "model_type": "toy_model",
            "confidence_cutoff": 0.6,
            "noise_ratio": 0.2,
            "rescale_ratio": None,
            "num_paths": 2,
            "max_iterations": 10,
            "batch_id": 1,
            "run_id": 1,
            "run_seed": 0
        }
    ]
}

run_dice_experiment.main(
    config=batch_config,
    is_experiment=False,
    verbose=True,
)

show_results('../experiment_results/dice_results/test_batch')
plt.title("Two runs with identical seeds are identical")
# Out:
# Got configs for 2 runs.
# Start executing 2 dice runs.
# 100%|██████████| 1/1 [00:00<00:00,  5.46it/s]
# Finished run 1/2
# 100%|██████████| 1/1 [00:00<00:00,  5.51it/s]
# Finished run 2/2
# Saved results to /home/jakeval/umass/research/MRMC/experiment_results/dice_results/test_batch
#
# Results saved as:
# ['experiment_config_df.csv', 'config.json', 'dice_paths_df.csv']
# Text(0.5, 1.0, 'Two runs with identical seeds are identical')

# %% [markdown]
# ### Test two runs with identical arguments but different seeds
#
# They should be similar but slightly different

# %%
batch_config = {
    "experiment_name": "test_batch",
    "run_configs": [
        {
            "dataset_name": "toy_data",
            "model_type": "toy_model",
            "confidence_cutoff": 0.6,
            "noise_ratio": 0.2,
            "rescale_ratio": None,
            "num_paths": 2,
            "max_iterations": 10,
            "batch_id": 0,
            "run_id": 0,
            "run_seed": 0
        },
        {
            "dataset_name": "toy_data",
            "model_type": "toy_model",
            "confidence_cutoff": 0.6,
            "noise_ratio": 0.2,
            "rescale_ratio": None,
            "num_paths": 2,
            "max_iterations": 10,
            "batch_id": 1,
            "run_id": 1,
            "run_seed": 1
        }
    ]
}

run_dice_experiment.main(
    config=batch_config,
    is_experiment=False,
    verbose=True,
)

show_results('../experiment_results/dice_results/test_batch')
plt.title("Different seeds for noise_ratio=0.1")
# Out:
# Got configs for 2 runs.
# Start executing 2 dice runs.
# 100%|██████████| 1/1 [00:00<00:00,  5.06it/s]
# Finished run 1/2
# 100%|██████████| 1/1 [00:00<00:00,  4.96it/s]
# Finished run 2/2
# Saved results to /home/jakeval/umass/research/MRMC/experiment_results/dice_results/test_batch
#
# Results saved as:
# ['experiment_config_df.csv', 'config.json', 'dice_paths_df.csv']
# Text(0.5, 1.0, 'Different seeds for noise_ratio=0.1')

# %% [markdown]
# # Test executing experiment configs

# %% [markdown]
# ### Test dry run

# %%
experiment_config = {
    "experiment_name": "test_experiment",
    "num_runs": 2,
    "random_seed": 0,
    "parameter_ranges": {
        "confidence_cutoff": [0.6],
        "noise_ratio": [None],
        "rescale_ratio": [None],
        "num_paths": [2],
        "dataset_name": ["toy_data"],
        "model_type": ["toy_model"],
        "max_iterations": [10],
    }
}

run_dice_experiment.main(
    config=experiment_config,
    is_experiment=True,
    verbose=True,
    dry_run=True,
)
# Out:
# Got configs for 2 runs.
# Terminate without executing runs because --dry_run is set.

# %% [markdown]
# ### Test multiple runs while varying noise_ratio
#
# There should be 4 runs total, making 8 paths.
#
# (2 paths per run, 2 runs per batch, 2 batches)

# %%
experiment_config = {
    "experiment_name": "test_experiment",
    "num_runs": 2,
    "random_seed": 0,
    "parameter_ranges": {
        "confidence_cutoff": [0.6],
        "noise_ratio": [0.05, 0.8],
        "rescale_ratio": [None],
        "num_paths": [2],
        "dataset_name": ["toy_data"],
        "model_type": ["toy_model"],
        "max_iterations": [10],
    }
}

run_dice_experiment.main(
    config=experiment_config,
    is_experiment=True,
    verbose=True,
    dry_run=False,
)

show_results('../experiment_results/dice_results/test_experiment', label_column='noise_ratio')
plt.title("Paths as noise_ratio changes")
# Out:
# Got configs for 4 runs.
# Start executing 4 dice runs.
# 100%|██████████| 1/1 [00:00<00:00,  4.99it/s]
# Finished run 1/4
# 100%|██████████| 1/1 [00:00<00:00,  5.49it/s]
# Finished run 2/4
# 100%|██████████| 1/1 [00:00<00:00,  5.13it/s]
# Finished run 3/4
# 100%|██████████| 1/1 [00:00<00:00,  4.64it/s]
# Finished run 4/4
# Saved results to /home/jakeval/umass/research/MRMC/experiment_results/dice_results/test_experiment
#
# Results saved as:
# ['experiment_config_df.csv', 'config.json', 'dice_paths_df.csv']
# Text(0.5, 1.0, 'Paths as noise_ratio changes')

# %% [markdown]
# ### Test limiting the number of runs

# %%
experiment_config = {
    "experiment_name": "test_experiment",
    "num_runs": 2,
    "random_seed": 0,
    "parameter_ranges": {
        "confidence_cutoff": [0.6],
        "noise_ratio": [0.05, 0.8],
        "rescale_ratio": [None],
        "num_paths": [2],
        "dataset_name": ["toy_data"],
        "model_type": ["toy_model"],
        "max_iterations": [10],
    }
}

run_dice_experiment.main(
    config=experiment_config,
    is_experiment=True,
    verbose=True,
    dry_run=False,
    max_runs=2
)

show_results('../experiment_results/dice_results/test_experiment', label_column='noise_ratio')
plt.title("Execute only 2 our of 4 runs")
# Out:
# Got configs for 4 runs.
# Throw out all but --max_runs=2 run_configs.
# Start executing 2 dice runs.
# 100%|██████████| 1/1 [00:00<00:00,  5.23it/s]
# Finished run 1/2
# 100%|██████████| 1/1 [00:00<00:00,  4.92it/s]
# Finished run 2/2
# Saved results to /home/jakeval/umass/research/MRMC/experiment_results/dice_results/test_experiment
#
# Results saved as:
# ['experiment_config_df.csv', 'config.json', 'dice_paths_df.csv']
# Text(0.5, 1.0, 'Execute only 2 our of 4 runs')

# %% [markdown]
# ### Test changing the results directory

# %%
experiment_config = {
    "experiment_name": "test_experiment",
    "num_runs": 1,
    "random_seed": 0,
    "parameter_ranges": {
        "confidence_cutoff": [0.6, 0.8],
        "noise_ratio": [0.1, 0.5],
        "rescale_ratio": [None],
        "num_paths": [2],
        "dataset_name": ["toy_data"],
        "model_type": ["toy_model"],
        "max_iterations": [10],
    }
}

results_dir = '../experiments_results/dice_results/test_results_dir'

run_dice_experiment.main(
    config=experiment_config,
    is_experiment=True,
    verbose=True,
    dry_run=False,
    results_dir=results_dir
)

show_results(results_dir)
plt.title("Paths as confidence_cutoff and noise_ratio change")
# Out:
# Got configs for 4 runs.
# Start executing 4 dice runs.
# 100%|██████████| 1/1 [00:00<00:00,  5.09it/s]
# Finished run 1/4
# 100%|██████████| 1/1 [00:00<00:00,  5.36it/s]
# Finished run 2/4
# 100%|██████████| 1/1 [00:00<00:00,  5.11it/s]
# Finished run 3/4
# 100%|██████████| 1/1 [00:00<00:00,  5.32it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.26it/s]
# Finished run 4/4
# Saved results to ../experiments_results/dice_results/test_results_dir
#
# Results saved as:
# ['experiment_config_df.csv', 'config.json', 'dice_paths_df.csv']
# Text(0.5, 1.0, 'Paths as confidence_cutoff and noise_ratio change')

# %% [markdown]
# # Test running distributed experiments

# %%
experiment_config = {
    "experiment_name": "test_experiment",
    "num_runs": 1,
    "random_seed": 0,
    "parameter_ranges": {
        "confidence_cutoff": [0.6, 0.7],
        "noise_ratio": [0.1, 0.5],
        "rescale_ratio": [None],
        "num_paths": [2],
        "dataset_name": ["toy_data"],
        "model_type": ["toy_model"],
        "max_iterations": [10],
    }
}

run_dice_experiment.main(
    config=experiment_config,
    is_experiment=True,
    verbose=True,
    dry_run=False,
    distributed=True,
    num_processes=2,
    use_slurm=False,
)

show_results('../experiment_results/dice_results/test_experiment', label_column='noise_ratio')
plt.title("Paths as confidence_cutoff and noise_ratio change")
# Out:
# Got configs for 4 runs.
# 4 runs will be distributed over 2 processes.
# Start executing 4 dice runs.
# Waiting for 2 processes to finish...
# 100%|██████████| 1/1 [00:00<00:00,  4.90it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.94it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.77it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.26it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Waiting for 1 processes to finish...
# 100%|██████████| 1/1 [00:00<00:00,  5.51it/s]
# Waiting for 0 processes to finish...
# Saved results to /home/jakeval/umass/research/MRMC/experiment_results/dice_results/test_experiment
#
# Results saved as:
# ['experiment_config_df.csv', 'config.json', 'dice_paths_df.csv']
# Text(0.5, 1.0, 'Paths as confidence_cutoff and noise_ratio change')

# %% [markdown]
# ### Test when setting a scratch directory

# %%
experiment_config = {
    "experiment_name": "test_experiment",
    "num_runs": 1,
    "random_seed": 0,
    "parameter_ranges": {
        "confidence_cutoff": [0.6, 0.8],
        "noise_ratio": [0.1, 0.5],
        "rescale_ratio": [None],
        "num_paths": [2],
        "dataset_name": ["toy_data"],
        "model_type": ["toy_model"],
        "max_iterations": [10],
    }
}

run_dice_experiment.main(
    config=experiment_config,
    is_experiment=True,
    verbose=True,
    dry_run=False,
    distributed=True,
    num_processes=2,
    use_slurm=False,
    scratch_dir='./'
)

show_results('../experiment_results/dice_results/test_experiment', label_column='noise_ratio')
plt.title("Paths as confidence_cutoff and noise_ratio change")
# Out:
# Got configs for 4 runs.
# 4 runs will be distributed over 2 processes.
# Start executing 4 dice runs.
# Waiting for 2 processes to finish...
# 100%|██████████| 1/1 [00:00<00:00,  5.28it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.91it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.74it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.60it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.89it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.55it/s]
# Waiting for 1 processes to finish...
# Waiting for 0 processes to finish...
# Saved results to /home/jakeval/umass/research/MRMC/experiment_results/dice_results/test_experiment
#
# Results saved as:
# ['experiment_config_df.csv', 'config.json', 'dice_paths_df.csv']
# 100%|██████████| 1/1 [00:00<00:00,  4.77it/s]
# Text(0.5, 1.0, 'Paths as confidence_cutoff and noise_ratio change')

# %% [markdown]
# ### Does it even use the scratch directory? Let's check
# We can give it a directory we know doesn't exist and it should fail.
#
# **We expect the following cell to throw an error**

# %%
experiment_config = {
    "experiment_name": "test_experiment",
    "num_runs": 1,
    "random_seed": 0,
    "parameter_ranges": {
        "confidence_cutoff": [0.6, 0.8],
        "noise_ratio": [0.1, 0.5],
        "rescale_ratio": [None],
        "num_paths": [2],
        "dataset_name": ["toy_data"],
        "model_type": ["toy_model"],
        "max_iterations": [10],
    }
}

run_dice_experiment.main(
    config=experiment_config,
    is_experiment=True,
    verbose=True,
    dry_run=False,
    distributed=True,
    num_processes=2,
    use_slurm=False,
    scratch_dir='/this-dir-doesnt-exist-and-if-it-does-on-your-machine-then-wow'
)

show_results('../experiment_results/dice_results/test_experiment', label_column='noise_ratio')
plt.title("Paths as confidence_cutoff and noise_ratio change")
# Out:
# Got configs for 4 runs.
# 4 runs will be distributed over 2 processes.
# Start executing 4 dice runs.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [26], line 16
#       1 experiment_config = {
#       2     "experiment_name": "test_experiment",
#       3     "num_runs": 1,
#    (...)
#      13     }
#      14 }
# ---> 16 run_dice_experiment.main(
#      17     config=experiment_config,
#      18     is_experiment=True,
#      19     verbose=True,
#      20     dry_run=False,
#      21     distributed=True,
#      22     num_processes=2,
#      23     use_slurm=False,
#      24     scratch_dir='/this-dir-doesnt-exist-and-if-it-does-on-your-machine-then-wow'
#      25 )
#      27 show_results('../experiment_results/dice_results/test_experiment', label_column='noise_ratio')
#      28 plt.title("Paths as confidence_cutoff and noise_ratio change")
#
# File ~/umass/research/MRMC/confidence_checks/../experiments/dice_experiment/run_dice_experiment.py:485, in main(config, is_experiment, max_runs, results_dir, verbose, dry_run, distributed, num_processes, use_slurm, scratch_dir, only_csv)
#     483     if verbose:
#     484         print(f"Start executing {len(run_configs)} dice runs.")
# --> 485     results = runner.execute_runs(run_configs)
#     486 else:
#     487     if verbose:
#
# File ~/umass/research/MRMC/confidence_checks/../experiments/parallel_runner.py:92, in ParallelRunner.execute_runs(self, run_configs)
#      89 if self.scratch_dir:
#      90     # ensure the scratch_dir is well-formatted.
#      91     scratch_dir = os.path.join(self.scratch_dir, "")
# ---> 92 with tempfile.TemporaryDirectory(prefix=scratch_dir) as scratch_dir:
#      93     scratch_results_dir = self.run_processes(
#      94         partitioned_run_configs, scratch_dir
#      95     )
#      96     return self.collect_results(scratch_results_dir)
#
# File /usr/lib/python3.8/tempfile.py:919, in TemporaryDirectory.__init__(self, suffix, prefix, dir)
#     918 def __init__(self, suffix=None, prefix=None, dir=None):
# --> 919     self.name = mkdtemp(suffix, prefix, dir)
#     920     self._finalizer = _weakref.finalize(
#     921         self, self._cleanup, self.name,
#     922         warn_message="Implicitly cleaning up {!r}".format(self))
#
# File /usr/lib/python3.8/tempfile.py:497, in mkdtemp(suffix, prefix, dir)
#     495 _sys.audit("tempfile.mkdtemp", file)
#     496 try:
# --> 497     _os.mkdir(file, 0o700)
#     498 except FileExistsError:
#     499     continue    # try again
#
# FileNotFoundError: [Errno 2] No such file or directory: '/this-dir-doesnt-exist-and-if-it-does-on-your-machine-then-wow/yestsbl2'
