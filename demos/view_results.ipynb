# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '..'))

# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from models import model_interface, model_loader, model_constants
from data import data_loader
from visualize import plot_paths

# %% [markdown]
# # Preliminaries -- load everything

# %%
DATASET, DATASET_INFO = data_loader.load_data(data_loader.DatasetName('credit_card_default'))
MODEL = model_loader.load_model(model_constants.ModelType('logistic_regression'), data_loader.DatasetName('credit_card_default'))

cluster_df = pd.read_csv('../experiment_results/mrmc_results/mrmc_hyperparam_experiment/cluster_df.csv')
index_df = pd.read_csv('../experiment_results/mrmc_results/mrmc_hyperparam_experiment/index_df.csv')
path_df = pd.read_csv('../experiment_results/mrmc_results/mrmc_hyperparam_experiment/path_df.csv')
index_df
# Out:
# ModelType.LOGISTIC_REGRESSION
#       batch_id  run_id  run_seed  cluster_seed  confidence_cutoff  \
# 0           43     434      4404       1834823                0.7
# 1           68     687      5653       1834823                0.7
# 2           51     511      3183       1834823                0.7
# 3            8      88      5323       1834823                0.7
# 4           41     412      1701       1834823                0.7
# ...        ...     ...       ...           ...                ...
# 1915       106    1067      5653       1834823                0.7
# 1916        70     709      1498       1834823                0.7
# 1917       159    1593       478       1834823                0.7
# 1918        17     177      5653       1834823                0.7
# 1919        66     660      7527       1834823                0.7
#
#                   dataset  max_iterations                model  noise_ratio  \
# 0     credit_card_default              30  logistic_regression          NaN
# 1     credit_card_default              30  logistic_regression          NaN
# 2     credit_card_default              30  logistic_regression          NaN
# 3     credit_card_default              30  logistic_regression          NaN
# 4     credit_card_default              30  logistic_regression          NaN
# ...                   ...             ...                  ...          ...
# 1915  credit_card_default              30  logistic_regression          NaN
# 1916  credit_card_default              30  logistic_regression          NaN
# 1917  credit_card_default              30  logistic_regression          NaN
# 1918  credit_card_default              30  logistic_regression          NaN
# 1919  credit_card_default              30  logistic_regression          NaN
#
#       num_paths  rescale_ratio  step_size  volcano_cutoff  volcano_degree
# 0             2            NaN       1.00            0.50               8
# 1             3            NaN       0.50            1.00               1
# 2             3            NaN       0.25            0.25               8
# 3             2            NaN       0.25            1.00               1
# 4             2            NaN       1.00            0.50               2
# ...         ...            ...        ...             ...             ...
# 1915          4            NaN       0.25            1.00               4
# 1916          3            NaN       0.50            1.00               4
# 1917          5            NaN       0.50            0.25               8
# 1918          2            NaN       0.50            0.50               2
# 1919          3            NaN       0.50            0.50               4
#
# [1920 rows x 14 columns]

# %%
def analyze_paths(paths, target_certainty):
    metrics = {
        'success_ratio': 0
    }
    for path in paths:
        if MODEL.predict_pos_proba_series(path.iloc[-1]) > target_certainty:
            metrics['success_ratio'] += 1

    metrics['success_ratio'] = metrics['success_ratio'] / len(paths)
    return metrics


def aggregate_metrics(run_metrics):
    aggregated_metrics = {}
    for metrics in run_metrics:
        for metric, metric_value in metrics.items():
            aggregated_metrics[metric] = aggregated_metrics.get(metric, []) + [metric_value]
    
    return pd.DataFrame(aggregated_metrics)


def analyze_runs(runs: pd.DataFrame, target_certainty, num_paths):
    run_metrics = []
    for run_id in runs.run_id.unique():
        paths = []
        run = runs[runs.run_id == run_id]
        for path_id in range(num_paths):
            path = run[run.path_id == path_id].sort_values(['step_id']).drop(columns=['batch_id', 'run_id', 'step_id', 'path_id'])
            paths.append(path)
        run_metrics.append(analyze_paths(paths, target_certainty))
    return aggregate_metrics(run_metrics)

# %% [markdown]
# # Analyze the results. This will take a while...
# Expect about 5-10 minutes.

# %%
final_results = None

batch_ids = index_df.batch_id.unique()

for i, batch_id in enumerate(batch_ids):
    print(f"Process batch {i+1}/{len(batch_ids)}")
    batched_runs = path_df[path_df.batch_id == batch_id]
    target_certainty = index_df[index_df.batch_id == batch_id].confidence_cutoff.iloc[0]
    num_paths = index_df[index_df.batch_id == batch_id].num_paths.iloc[0]

    metrics_df = analyze_runs(batched_runs, target_certainty, num_paths)
    metrics_df['batch_id'] = batch_id
    if final_results is not None:
        final_results = pd.concat([final_results, metrics_df]).reset_index(drop=True)
    else:
        final_results = metrics_df
# Out:
# Process batch 1/192
# Process batch 2/192
# Process batch 3/192
# Process batch 4/192
# Process batch 5/192
# Process batch 6/192
# Process batch 7/192
# Process batch 8/192
# Process batch 9/192
# Process batch 10/192
# Process batch 11/192
# Process batch 12/192
# Process batch 13/192
# Process batch 14/192
# Process batch 15/192
# Process batch 16/192
# Process batch 17/192
# Process batch 18/192
# Process batch 19/192
# Process batch 20/192
# Process batch 21/192
# Process batch 22/192
# Process batch 23/192
# Process batch 24/192
# Process batch 25/192
# Process batch 26/192
# Process batch 27/192
# Process batch 28/192
# Process batch 29/192
# Process batch 30/192
# Process batch 31/192
# Process batch 32/192
# Process batch 33/192
# Process batch 34/192
# Process batch 35/192
# Process batch 36/192
# Process batch 37/192
# Process batch 38/192
# Process batch 39/192
# Process batch 40/192
# Process batch 41/192
# Process batch 42/192
# Process batch 43/192
# Process batch 44/192
# Process batch 45/192
# Process batch 46/192
# Process batch 47/192
# Process batch 48/192
# Process batch 49/192
# Process batch 50/192
# Process batch 51/192
# Process batch 52/192
# Process batch 53/192
# Process batch 54/192
# Process batch 55/192
# Process batch 56/192
# Process batch 57/192
# Process batch 58/192
# Process batch 59/192
# Process batch 60/192
# Process batch 61/192
# Process batch 62/192
# Process batch 63/192
# Process batch 64/192
# Process batch 65/192
# Process batch 66/192
# Process batch 67/192
# Process batch 68/192
# Process batch 69/192
# Process batch 70/192
# Process batch 71/192
# Process batch 72/192
# Process batch 73/192
# Process batch 74/192
# Process batch 75/192
# Process batch 76/192
# Process batch 77/192
# Process batch 78/192
# Process batch 79/192
# Process batch 80/192
# Process batch 81/192
# Process batch 82/192
# Process batch 83/192
# Process batch 84/192
# Process batch 85/192
# Process batch 86/192
# Process batch 87/192
# Process batch 88/192
# Process batch 89/192
# Process batch 90/192
# Process batch 91/192
# Process batch 92/192
# Process batch 93/192
# Process batch 94/192
# Process batch 95/192
# Process batch 96/192
# Process batch 97/192
# Process batch 98/192
# Process batch 99/192
# Process batch 100/192
# Process batch 101/192
# Process batch 102/192
# Process batch 103/192
# Process batch 104/192
# Process batch 105/192
# Process batch 106/192
# Process batch 107/192
# Process batch 108/192
# Process batch 109/192
# Process batch 110/192
# Process batch 111/192
# Process batch 112/192
# Process batch 113/192
# Process batch 114/192
# Process batch 115/192
# Process batch 116/192
# Process batch 117/192
# Process batch 118/192
# Process batch 119/192
# Process batch 120/192
# Process batch 121/192
# Process batch 122/192
# Process batch 123/192
# Process batch 124/192
# Process batch 125/192
# Process batch 126/192
# Process batch 127/192
# Process batch 128/192
# Process batch 129/192
# Process batch 130/192
# Process batch 131/192
# Process batch 132/192
# Process batch 133/192
# Process batch 134/192
# Process batch 135/192
# Process batch 136/192
# Process batch 137/192
# Process batch 138/192
# Process batch 139/192
# Process batch 140/192
# Process batch 141/192
# Process batch 142/192
# Process batch 143/192
# Process batch 144/192
# Process batch 145/192
# Process batch 146/192
# Process batch 147/192
# Process batch 148/192
# Process batch 149/192
# Process batch 150/192
# Process batch 151/192
# Process batch 152/192
# Process batch 153/192
# Process batch 154/192
# Process batch 155/192
# Process batch 156/192
# Process batch 157/192
# Process batch 158/192
# Process batch 159/192
# Process batch 160/192
# Process batch 161/192
# Process batch 162/192
# Process batch 163/192
# Process batch 164/192
# Process batch 165/192
# Process batch 166/192
# Process batch 167/192
# Process batch 168/192
# Process batch 169/192
# Process batch 170/192
# Process batch 171/192
# Process batch 172/192
# Process batch 173/192
# Process batch 174/192
# Process batch 175/192
# Process batch 176/192
# Process batch 177/192
# Process batch 178/192
# Process batch 179/192
# Process batch 180/192
# Process batch 181/192
# Process batch 182/192
# Process batch 183/192
# Process batch 184/192
# Process batch 185/192
# Process batch 186/192
# Process batch 187/192
# Process batch 188/192
# Process batch 189/192
# Process batch 190/192
# Process batch 191/192
# Process batch 192/192

# %% [markdown]
# ## Did we collect enough samples? Let's look at variance
#
# It ranges from 0 (hurray!) to 0.4 (uh oh!). Why are some of the variances so high?

# %%
final_results.groupby('batch_id').std()
final_results = final_results.rename(columns={'success_ratio': 'std_dev_of_success_ratio'}).sort_values('std_dev_of_success_ratio')
final_results
# Out:
#       std_dev_of_success_ratio  batch_id
# 250                        0.0       105
# 1452                       0.0        99
# 276                        0.0         0
# 73                         0.0        10
# 188                        0.0       150
# ...                        ...       ...
# 670                        1.0       114
# 669                        1.0       190
# 668                        1.0       190
# 634                        1.0        98
# 1919                       1.0        92
#
# [1920 rows x 2 columns]

# %% [markdown]
# ### We can plot the standard deviation
#
# It's hard to interpret this plot. Maybe there are some runs with low standard
# deviation and some with high standard deviation?

# %%
run_subset_dfs = []
for n_runs in [2, 4, 6, 8, 10]:
    df = final_results.groupby('batch_id').sample(n=n_runs, replace=False).groupby('batch_id').std().sort_values('std_dev_of_success_ratio')
    df['batch_id'] = df.index
    df['n_runs'] = n_runs
    run_subset_dfs.append(df)

std_dev_vs_n_runs_df = pd.concat(run_subset_dfs).reset_index(drop=True)
sns.lineplot(std_dev_vs_n_runs_df, x='n_runs', y='std_dev_of_success_ratio', hue='batch_id')
# Out:
# <AxesSubplot: xlabel='n_runs', ylabel='std_dev_of_success_ratio'>

# %% [markdown]
# ### Most runs have low standard deviation, but some have high standard deviation

# %%
low_standard_dev_results = std_dev_vs_n_runs_df[(std_dev_vs_n_runs_df.n_runs == 10) & (std_dev_vs_n_runs_df.std_dev_of_success_ratio < 0.2)]
high_standard_dev_results = std_dev_vs_n_runs_df[(std_dev_vs_n_runs_df.n_runs == 10) & (std_dev_vs_n_runs_df.std_dev_of_success_ratio >= 0.2)]

print(f"There are {len(low_standard_dev_results)} batches with low standard deviation")
print(f"There are {len(high_standard_dev_results)} batches with high standard deviation")
# Out:
# There are 144 batches with low standard deviation
# There are 48 batches with high standard deviation

# %% [markdown]
# ### Only batches with step_size = 0.25 have high standard deviation
#
# Why?

# %%
high_dev_ids = high_standard_dev_results.batch_id.unique()
low_dev_ids = low_standard_dev_results.batch_id.unique()

low_counts = index_df[index_df.batch_id.isin(low_dev_ids)].drop_duplicates('batch_id').groupby('step_size').count()[['batch_id']]
low_counts['std_dev'] = '< 0.2'

high_counts = index_df[index_df.batch_id.isin(high_dev_ids)].drop_duplicates('batch_id').groupby('step_size').count()[['batch_id']]
high_counts['std_dev'] = '>= 0.2'

pd.concat([low_counts, high_counts]).sort_values('step_size')
# Out:
#            batch_id std_dev
# step_size
# 0.25             48  >= 0.2
# 0.50             48   < 0.2
# 0.75             48   < 0.2
# 1.00             48   < 0.2

# %% [markdown]
# ## Get more data on step_size=0.25
#
# This is the step size with high variance. Does it ever stabilize?

# %%
cluster_df_2 = pd.read_csv('../experiment_results/mrmc_results/mrmc_hyperparam_experiment_high_var/cluster_df.csv')
index_df_2 = pd.read_csv('../experiment_results/mrmc_results/mrmc_hyperparam_experiment_high_var/index_df.csv')
path_df_2 = pd.read_csv('../experiment_results/mrmc_results/mrmc_hyperparam_experiment_high_var/path_df.csv')
index_df_2
# Out:
#       batch_id  run_id  run_seed  cluster_seed  confidence_cutoff  \
# 0            3     107      1573       1834823                0.7
# 1           24     724      4404       1834823                0.7
# 2           44    1328      5323       1834823                0.7
# 3           34    1040      9560       1834823                0.7
# 4            5     170      9560       1834823                0.7
# ...        ...     ...       ...           ...                ...
# 1435         1      41      7699       1834823                0.7
# 1436         0       6      4340       1834823                0.7
# 1437        44    1331      7699       1834823                0.7
# 1438        29     882      4470       1834823                0.7
# 1439        39    1186      5500       1834823                0.7
#
#                   dataset  max_iterations                model  noise_ratio  \
# 0     credit_card_default              30  logistic_regression          NaN
# 1     credit_card_default              30  logistic_regression          NaN
# 2     credit_card_default              30  logistic_regression          NaN
# 3     credit_card_default              30  logistic_regression          NaN
# 4     credit_card_default              30  logistic_regression          NaN
# ...                   ...             ...                  ...          ...
# 1435  credit_card_default              30  logistic_regression          NaN
# 1436  credit_card_default              30  logistic_regression          NaN
# 1437  credit_card_default              30  logistic_regression          NaN
# 1438  credit_card_default              30  logistic_regression          NaN
# 1439  credit_card_default              30  logistic_regression          NaN
#
#       num_paths  rescale_ratio  step_size  volcano_cutoff  volcano_degree
# 0             2            NaN       0.25            0.25               8
# 1             4            NaN       0.25            0.25               1
# 2             5            NaN       0.25            1.00               1
# 3             4            NaN       0.25            1.00               4
# 4             2            NaN       0.25            0.50               2
# ...         ...            ...        ...             ...             ...
# 1435          2            NaN       0.25            0.25               2
# 1436          2            NaN       0.25            0.25               1
# 1437          5            NaN       0.25            1.00               1
# 1438          4            NaN       0.25            0.50               2
# 1439          5            NaN       0.25            0.25               8
#
# [1440 rows x 14 columns]

# %%
final_results = None

batch_ids = index_df_2.batch_id.unique()

for i, batch_id in enumerate(batch_ids):
    print(f"Process batch {i+1}/{len(batch_ids)}")
    batched_runs = path_df_2[path_df_2.batch_id == batch_id]
    target_certainty = index_df_2[index_df_2.batch_id == batch_id].confidence_cutoff.iloc[0]
    num_paths = index_df_2[index_df_2.batch_id == batch_id].num_paths.iloc[0]

    metrics_df = analyze_runs(batched_runs, target_certainty, num_paths)
    metrics_df['batch_id'] = batch_id
    if final_results is not None:
        final_results = pd.concat([final_results, metrics_df]).reset_index(drop=True)
    else:
        final_results = metrics_df
# Out:
# Process batch 1/48
# Process batch 2/48
# Process batch 3/48
# Process batch 4/48
# Process batch 5/48
# Process batch 6/48
# Process batch 7/48
# Process batch 8/48
# Process batch 9/48
# Process batch 10/48
# Process batch 11/48
# Process batch 12/48
# Process batch 13/48
# Process batch 14/48
# Process batch 15/48
# Process batch 16/48
# Process batch 17/48
# Process batch 18/48
# Process batch 19/48
# Process batch 20/48
# Process batch 21/48
# Process batch 22/48
# Process batch 23/48
# Process batch 24/48
# Process batch 25/48
# Process batch 26/48
# Process batch 27/48
# Process batch 28/48
# Process batch 29/48
# Process batch 30/48
# Process batch 31/48
# Process batch 32/48
# Process batch 33/48
# Process batch 34/48
# Process batch 35/48
# Process batch 36/48
# Process batch 37/48
# Process batch 38/48
# Process batch 39/48
# Process batch 40/48
# Process batch 41/48
# Process batch 42/48
# Process batch 43/48
# Process batch 44/48
# Process batch 45/48
# Process batch 46/48
# Process batch 47/48
# Process batch 48/48

# %%
std_dev_results = final_results.groupby('batch_id').std().rename(columns={'success_ratio': 'std_dev_of_success_ratio'}).sort_values('std_dev_of_success_ratio')
std_dev_results
# Out:
#           std_dev_of_success_ratio
# batch_id
# 35                        0.304303
# 31                        0.304303
# 27                        0.304303
# 34                        0.311305
# 26                        0.311305
# 30                        0.311305
# 33                        0.319505
# 29                        0.319505
# 25                        0.319505
# 47                        0.320918
# 43                        0.320918
# 39                        0.320918
# 19                        0.326755
# 15                        0.326755
# 23                        0.326755
# 24                        0.329249
# 32                        0.329249
# 28                        0.329249
# 11                        0.330447
# 7                         0.330447
# 3                         0.330447
# 38                        0.330864
# 42                        0.330864
# 46                        0.330864
# 10                        0.334338
# 6                         0.334338
# 2                         0.334338
# 22                        0.338278
# 18                        0.338278
# 14                        0.338278
# 1                         0.340723
# 9                         0.340723
# 8                         0.340723
# 5                         0.340723
# 4                         0.340723
# 0                         0.340723
# 37                        0.343143
# 41                        0.343143
# 45                        0.343143
# 40                        0.344747
# 44                        0.344747
# 36                        0.344747
# 21                        0.364623
# 13                        0.364623
# 20                        0.364623
# 12                        0.364623
# 17                        0.364623
# 16                        0.364623

# %%
run_subset_dfs = []
for n_runs in range(2, 31):
    df = final_results.groupby('batch_id').sample(n=n_runs, replace=False).groupby('batch_id').std().sort_values('success_ratio')
    df['batch_id'] = df.index
    df['n_runs'] = n_runs
    run_subset_dfs.append(df)

std_dev_vs_n_runs_df = pd.concat(run_subset_dfs).reset_index(drop=True).rename(columns={'success_ratio': 'std_dev_of_success_ratio'})
sns.lineplot(std_dev_vs_n_runs_df, x='n_runs', y='std_dev_of_success_ratio', hue='batch_id')
# Out:
# <AxesSubplot: xlabel='n_runs', ylabel='std_dev_of_success_ratio'>

# %%
mean_results = final_results.groupby('batch_id').mean().sort_values('success_ratio').rename(columns={'success_ratio': 'avg_success_ratio'})

results = pd.merge(mean_results, index_df_2.drop_duplicates('batch_id')[['batch_id', 'num_paths', 'step_size', 'volcano_cutoff', 'volcano_degree']], on='batch_id')
results
# Out:
#     batch_id  avg_success_ratio  num_paths  step_size  volcano_cutoff  \
# 0         44           0.633333          5       0.25            1.00
# 1         40           0.633333          5       0.25            0.50
# 2         21           0.633333          3       0.25            1.00
# 3         36           0.633333          5       0.25            0.25
# 4         20           0.633333          3       0.25            1.00
# 5         12           0.633333          3       0.25            0.25
# 6         13           0.633333          3       0.25            0.25
# 7         17           0.633333          3       0.25            0.50
# 8         16           0.633333          3       0.25            0.50
# 9         45           0.646667          5       0.25            1.00
# 10        41           0.646667          5       0.25            0.50
# 11        37           0.646667          5       0.25            0.25
# 12        28           0.675000          4       0.25            0.50
# 13        32           0.675000          4       0.25            1.00
# 14        24           0.675000          4       0.25            0.25
# 15        22           0.688889          3       0.25            1.00
# 16        23           0.688889          3       0.25            1.00
# 17        14           0.688889          3       0.25            0.25
# 18        18           0.688889          3       0.25            0.50
# 19        19           0.688889          3       0.25            0.50
# 20        15           0.688889          3       0.25            0.25
# 21        29           0.691667          4       0.25            0.50
# 22        33           0.691667          4       0.25            1.00
# 23        25           0.691667          4       0.25            0.25
# 24        38           0.713333          5       0.25            0.25
# 25        46           0.713333          5       0.25            1.00
# 26        42           0.713333          5       0.25            0.50
# 27        39           0.733333          5       0.25            0.25
# 28        43           0.733333          5       0.25            0.50
# 29         0           0.733333          2       0.25            0.25
# 30         8           0.733333          2       0.25            1.00
# 31         1           0.733333          2       0.25            0.25
# 32         4           0.733333          2       0.25            0.50
# 33         5           0.733333          2       0.25            0.50
# 34         9           0.733333          2       0.25            1.00
# 35        47           0.733333          5       0.25            1.00
# 36        34           0.741667          4       0.25            1.00
# 37        27           0.741667          4       0.25            0.25
# 38        26           0.741667          4       0.25            0.25
# 39        31           0.741667          4       0.25            0.50
# 40        35           0.741667          4       0.25            1.00
# 41        30           0.741667          4       0.25            0.50
# 42        10           0.816667          2       0.25            1.00
# 43         6           0.816667          2       0.25            0.50
# 44         2           0.816667          2       0.25            0.25
# 45         7           0.833333          2       0.25            0.50
# 46        11           0.833333          2       0.25            1.00
# 47         3           0.833333          2       0.25            0.25
#
#     volcano_degree
# 0                1
# 1                1
# 2                2
# 3                1
# 4                1
# 5                1
# 6                2
# 7                2
# 8                1
# 9                2
# 10               2
# 11               2
# 12               1
# 13               1
# 14               1
# 15               4
# 16               8
# 17               4
# 18               4
# 19               8
# 20               8
# 21               2
# 22               2
# 23               2
# 24               4
# 25               4
# 26               4
# 27               8
# 28               8
# 29               1
# 30               1
# 31               2
# 32               1
# 33               2
# 34               2
# 35               8
# 36               4
# 37               8
# 38               4
# 39               8
# 40               8
# 41               4
# 42               4
# 43               4
# 44               4
# 45               8
# 46               8
# 47               8

# %% [markdown]
# ### Why do the paths sometimes fail?
#
# Visualize some of the paths

# %%
def random_run(batch: pd.DataFrame, seed: int):
    run_id = np.random.default_rng(seed).choice(batch.run_id.unique(), 1)[0]
    run = batch[batch.run_id == run_id]
    paths = []
    path_ids = sorted(run.path_id.unique())
    for path_id in path_ids:
        path = run[run.path_id == path_id].sort_values('step_id').drop(columns=['step_id', 'path_id', 'run_id', 'batch_id'])
        paths.append(path)
    return paths

paths = random_run(path_df_2[path_df_2.batch_id == 21], 129348)

for i, path in enumerate(paths):
    proba = MODEL.predict_pos_proba_series(path.iloc[-1])
    cutoff = index_df_2.confidence_cutoff.unique()[0]
    if proba > cutoff:
        print(f"Path {i} succeeds with probability {proba} > {cutoff}")
    else:
        print(f"Path {i} fails with probability {proba} <= {cutoff}")
# Out:
# Path 0 fails with probability 0.5610064107110914 <= 0.7
# Path 1 fails with probability 0.658851722282183 <= 0.7
# Path 2 fails with probability 0.27386006278441766 <= 0.7

# %%
plot_paths.plot_stuff(
    model=MODEL,
    dataset=DATASET,
    dataset_info=DATASET_INFO,
    paths=paths,
    confidence_cutoff=None,
    xlim=(-6, 22),
    ylim=(-10, 20)
)
# Out:
# /home/jakeval/umass/research/.venv/lib/python3.8/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# # Let's look at the average over low standard deviation samples
#
# We see that the results are fairly stable -- the average success ratio is high.

# %%
result_subset = final_results[final_results.batch_id.isin(low_dev_ids)]

mean_results = result_subset.groupby('batch_id').mean().sort_values('success_ratio')
mean_results
# Out:
#           success_ratio
# batch_id
# 71             0.933333
# 63             0.933333
# 67             0.933333
# 115            0.950000
# 111            0.950000
# ...                 ...
# 45             1.000000
# 44             1.000000
# 43             1.000000
# 190            1.000000
# 191            1.000000
#
# [144 rows x 1 columns]

# %%
results = pd.merge(mean_results, index_df[['batch_id', 'num_paths', 'step_size', 'volcano_cutoff', 'volcano_degree']], on='batch_id')
results
# Out:
#       batch_id  success_ratio  num_paths  step_size  volcano_cutoff  \
# 0           71       0.933333          3        0.5             1.0
# 1           71       0.933333          3        0.5             1.0
# 2           71       0.933333          3        0.5             1.0
# 3           71       0.933333          3        0.5             1.0
# 4           71       0.933333          3        0.5             1.0
# ...        ...            ...        ...        ...             ...
# 1435       191       1.000000          5        1.0             1.0
# 1436       191       1.000000          5        1.0             1.0
# 1437       191       1.000000          5        1.0             1.0
# 1438       191       1.000000          5        1.0             1.0
# 1439       191       1.000000          5        1.0             1.0
#
#       volcano_degree
# 0                  8
# 1                  8
# 2                  8
# 3                  8
# 4                  8
# ...              ...
# 1435               8
# 1436               8
# 1437               8
# 1438               8
# 1439               8
#
# [1440 rows x 6 columns]

# %% [markdown]
# ## Total Distribution

# %%
sns.displot(results, x='success_ratio')

# %% [markdown]
# ## Step Size
#
# Some of the paths with step size 0.5 don't succeed. Why not?

# %%
sns.displot(results[results.step_size == 0.75], x='success_ratio')

# %%
results
# Out:
#       batch_id  success_ratio  num_paths  step_size  volcano_cutoff  \
# 0           57            0.7          3       0.25             1.0
# 1           57            0.7          3       0.25             1.0
# 2           57            0.7          3       0.25             1.0
# 3           57            0.7          3       0.25             1.0
# 4           57            0.7          3       0.25             1.0
# ...        ...            ...        ...        ...             ...
# 1915       191            1.0          5       1.00             1.0
# 1916       191            1.0          5       1.00             1.0
# 1917       191            1.0          5       1.00             1.0
# 1918       191            1.0          5       1.00             1.0
# 1919       191            1.0          5       1.00             1.0
#
#       volcano_degree
# 0                  2
# 1                  2
# 2                  2
# 3                  2
# 4                  2
# ...              ...
# 1915               8
# 1916               8
# 1917               8
# 1918               8
# 1919               8
#
# [1920 rows x 6 columns]
